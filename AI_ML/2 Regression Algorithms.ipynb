# %%
# Do the necessary imports
import numpy as np # Num - Numerical, Py - Python. This is the numerical python library
import pandas as pd # Pandas is a data manipulation library
import matplotlib.pyplot as plt # Matplotlib is a plotting library. pyplot is the module that provides a MATLAB-like interface
import seaborn as sns # Seaborn is an advanced plotting library built on top of matplotlib

import warnings # This module is used to ignore warnings that are thrown by the seaborn library
warnings.filterwarnings('ignore')

# %%
# Dataset link:
# https://raw.githubusercontent.com/ingledarshan/upGrad_Darshan/refs/heads/main/Advertising.csv

df = pd.read_csv("Advertising.csv") # Load the dataset

# %%
# Print the total number of rows and columns in the dataset - shape attribute
print(df.shape)
# Out:
# (200, 5)

# %%
# Print the first 5 rows of the dataset - head() method
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True) # Drop the 'Unnamed: 0' column
# axis=1 specifies that the column is to be dropped
# inplace=True specifies that the changes are to be made in the original dataframe
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Problem Statement: Predict the sales based on the advertising costs

# Column Descriptions:
# TV: Advertising costs on TV (in thousands of dollars)
# Radio: Advertising costs on Radio (in thousands of dollars)
# Newspaper: Advertising costs on Newspaper (in thousands of dollars)
# Sales: Sales of the product (in thousands of units)

# Your role as a Data Scientist is to find:
# 1. The relationship between the features and the response
# 2. Predict the sales based on the advertising costs
# 2. Determine which media contributes to sales

# %% [markdown]
# ### Various regression algorithms
#
# #### Don't Let Data Fool You! This Is How Industry Experts Choose The Right Regression Algorithm
#
# https://www.linkedin.com/posts/drdarshaningle-instructor_want-to-know-choosing-the-right-regression-activity-7159395083413274624-8DN3?utm_source=share&utm_medium=member_desktop
#
# 1. Linear Regression
# 2. Logistic Regression (not actually a regression algorithm. Please ignore this.)
# 3. Polynomial Regression
# 4. Ridge Regression
# 5. Lasso Regression
# 6. Elastic Net Regression
# 7. Stepwise Regression
# 8. Bayesian Linear Regression
# 9. Principal Component Regression (PCR)
# 10. Quantile Regression
# 11. Least Absolute Shrinkage and Selection Operator (LASSO)
# 12. Support Vector Regression (SVR)
# 13. Decision Tree Regression
# 14. Random Forest Regression
# 15. Gradient Boosting Regression (e.g., XGBoost, LightGBM, CatBoost)
# 16. AdaBoost Regression
# 17. K-Nearest Neighbors (KNN) Regression
# 18. Multi-task Learning Regression
# 19. Ridge Polynomial Regression
# 20. Robust Regression (e.g., RANSAC, Huber)

# %%
df.describe() # Get the summary statistics of the dataset
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.info() # Get the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# Implement Linear Regression
# This algorithm expects a linear relationship between the features and the response
# The relationship is of the form: Y = m1X1 + m2X2 + m3X3 + c

# %%
sns.scatterplot(x='TV', y='sales', data=df) # Scatter plot of TV vs Sales
plt.show() # Display the plot

# %%
sns.scatterplot(x='radio', y='sales', data=df) # Scatter plot of Radio vs Sales
plt.show() # Display the plot

# %%
sns.scatterplot(x='newspaper', y='sales', data=df) # Scatter plot of Newspaper vs Sales
plt.show() # Display the plot

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Divide the dataset into features and response
X = df.drop(['sales'], axis=1) # Features
y = df['sales'] # Response

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
# https://scikit-learn.org/1.5/modules/generated/sklearn.model_selection.train_test_split.html
from sklearn.model_selection import train_test_split # Import the train_test_split function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# random_state=0 specifies that the random number generator is the RandomState instance
# test_size=0.2 specifies that 20% of the data is to be used for testing
# random_state can take any integer value. It is used to reproduce the same results across different runs
# The value that random_state takes ranges from 0 to 4294967296 i.e. 0 to 2^32-1
# Some popular values are 0, 1, 42, 100, 123. These values are used to reproduce the same results across different runs

X_train.head()
# Out:
#         TV  radio  newspaper
# 134   36.9   38.6       65.6
# 66    31.5   24.6        2.2
# 26   142.9   29.3       12.6
# 113  209.6   20.6       10.7
# 168  215.4   23.6       57.6

# %%
X_train.describe()
# Out:
#                TV       radio   newspaper
# count  160.000000  160.000000  160.000000
# mean   150.518125   23.388125   30.125625
# std     84.957371   14.736240   21.444814
# min      4.100000    0.000000    0.900000
# 25%     76.375000    9.525000   11.675000
# 50%    157.400000   24.300000   25.900000
# 75%    220.350000   36.350000   45.100000
# max    296.400000   49.600000  100.900000

# %%
features = ['TV', 'radio', 'newspaper'] # List of features
features
# Out:
# ['TV', 'radio', 'newspaper']

# %%
# MinMax Scaling
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
# MinMaxScaler scales the data to a fixed range [0, 1]
from sklearn.preprocessing import MinMaxScaler # Import the MinMaxScaler class
mms = MinMaxScaler() # Create an instance of the MinMaxScaler class
X_train[features] = mms.fit_transform(X_train[features]) # fit means studying the data, transform means change the data in the range [0, 1]
X_test[features] = mms.transform(X_test[features]) # transform means change the data in the range [0, 1]

# %%
X_train.describe()
# Out:
#                TV       radio   newspaper
# count  160.000000  160.000000  160.000000
# mean     0.500917    0.471535    0.292256
# std      0.290651    0.297102    0.214448
# min      0.000000    0.000000    0.000000
# 25%      0.247263    0.192036    0.107750
# 50%      0.524461    0.489919    0.250000
# 75%      0.739822    0.732863    0.442000
# max      1.000000    1.000000    1.000000

# %%
# Lets create a Linear Regression model
# https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.LinearRegression.html
from sklearn.linear_model import LinearRegression # Import the LinearRegression class
lr = LinearRegression() # Create an instance of the LinearRegression class
lr.fit(X_train, y_train) # # fit means studying the data
y_pred_train = lr.predict(X_train) # predict the response on the training data
y_pred_test = lr.predict(X_test) # predict the response on the testing data
from sklearn.metrics import r2_score # Import the r2_score function. This will give value beween [0, 1], higher the better. 0.8 is good
train_accuracy = r2_score(y_train, y_pred_train) # Calculate the R2 score on the training data
test_accuracy = r2_score(y_test, y_pred_test) # Calculate the R2 score on the testing data
print("Training Accuracy: ", train_accuracy) # Print the training accuracy
print("Testing Accuracy: ", test_accuracy) # Print the testing accuracy
# Out:
# Training Accuracy:  0.9067114990146383
# Testing Accuracy:  0.8601145185017868

# %%
# Lets create a Support Vector Regression model
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html
from sklearn.svm import SVR # Import the SVR class
svr = SVR() # Create an instance of the SVR class
svr.fit(X_train, y_train) # fit means studying the data
y_pred_train = svr.predict(X_train) # predict the response on the training data
y_pred_test = svr.predict(X_test) # predict the response on the testing data
train_accuracy = r2_score(y_train, y_pred_train) # Calculate the R2 score on the training data
test_accuracy = r2_score(y_test, y_pred_test) # Calculate the R2 score on the testing data
print("Training Accuracy: ", train_accuracy) # Print the training accuracy
print("Testing Accuracy: ", test_accuracy) # Print the testing accuracy
# Out:
# Training Accuracy:  0.9406499330825828
# Testing Accuracy:  0.8891707961888985

# %%
# Qunatify what is a good model:
# (Train Accuracy - Test Accuracy) <= 0.05
# Train Accuracy >= 0.8
# If both the above conditions are satisfied, then the model is a good model

# %%
# Lets create a AdaBoost Regression model
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostRegressor.html
from sklearn.ensemble import AdaBoostRegressor # Import the AdaBoostRegressor class
abr = AdaBoostRegressor() # Create an instance of the AdaBoostRegressor class
abr.fit(X_train, y_train) # fit means studying the data
y_pred_train = abr.predict(X_train) # predict the response on the training data
y_pred_test = abr.predict(X_test) # predict the response on the testing data
train_accuracy = r2_score(y_train, y_pred_train) # Calculate the R2 score on the training data
test_accuracy = r2_score(y_test, y_pred_test) # Calculate the R2 score on the testing data
print("Training Accuracy: ", train_accuracy) # Print the training accuracy
print("Testing Accuracy: ", test_accuracy) # Print the testing accuracy
# Out:
# Training Accuracy:  0.9782966874505543
# Testing Accuracy:  0.9506603804062446

# %%
# Lets implement the CatBoost Regressor
# Install the catboost library. -q means quiet mode
# !pip install catboost -q
from catboost import CatBoostRegressor # Import the CatBoostRegressor class
cbr = CatBoostRegressor(depth=2, iterations=500, learning_rate=0.1) # Create an instance of the CatBoostRegressor class
cbr.fit(X_train, y_train) # fit means studying the data
y_pred_train = cbr.predict(X_train) # predict the response on the training data
y_pred_test = cbr.predict(X_test) # predict the response on the testing data
train_accuracy = r2_score(y_train, y_pred_train) # Calculate the R2 score on the training data
test_accuracy = r2_score(y_test, y_pred_test) # Calculate the R2 score on the testing data
# 461:	learn: 0.2344759	total: 97.3ms	remaining: 8ms
# 462:	learn: 0.2343877	total: 97.3ms	remaining: 7.78ms
# 463:	learn: 0.2342728	total: 97.4ms	remaining: 7.55ms
# 464:	learn: 0.2337112	total: 97.4ms	remaining: 7.33ms
# 465:	learn: 0.2332250	total: 97.5ms	remaining: 7.11ms
# 466:	learn: 0.2329962	total: 97.6ms	remaining: 6.89ms
# 467:	learn: 0.2327116	total: 97.6ms	remaining: 6.67ms
# 468:	learn: 0.2325608	total: 97.7ms	remaining: 6.46ms
# 469:	learn: 0.2323875	total: 97.8ms	remaining: 6.24ms
# 470:	learn: 0.2319769	total: 97.8ms	remaining: 6.02ms
# 471:	learn: 0.2318413	total: 97.9ms	remaining: 5.81ms
# 472:	learn: 0.2317166	total: 97.9ms	remaining: 5.59ms
# 473:	learn: 0.2313082	total: 98ms	remaining: 5.38ms
# 474:	learn: 0.2307784	total: 98.1ms	remaining: 5.16ms
# 475:	learn: 0.2305057	total: 98.1ms	remaining: 4.95ms
# 476:	learn: 0.2301244	total: 98.2ms	remaining: 4.74ms
# 477:	learn: 0.2299150	total: 98.3ms	remaining: 4.52ms
# 478:	learn: 0.2295447	total: 98.3ms	remaining: 4.31ms
# 479:	learn: 0.2293300	total: 98.4ms	remaining: 4.1ms
# 480:	learn: 0.2291715	total: 98.5ms	remaining: 3.89ms
# 481:	learn: 0.2289821	total: 98.5ms	remaining: 3.68ms
# 482:	learn: 0.2286329	total: 98.6ms	remaining: 3.47ms
# 483:	learn: 0.2282856	total: 98.6ms	remaining: 3.26ms
# 484:	learn: 0.2279334	total: 98.7ms	remaining: 3.05ms
# 485:	learn: 0.2277076	total: 98.7ms	remaining: 2.84ms
# 486:	learn: 0.2275132	total: 98.8ms	remaining: 2.64ms
# 487:	learn: 0.2273998	total: 98.8ms	remaining: 2.43ms
# 488:	learn: 0.2267725	total: 99ms	remaining: 2.23ms
# 489:	learn: 0.2265662	total: 99ms	remaining: 2.02ms
# 490:	learn: 0.2262508	total: 99ms	remaining: 1.81ms
# 491:	learn: 0.2259285	total: 99.1ms	remaining: 1.61ms
# 492:	learn: 0.2256570	total: 99.2ms	remaining: 1.41ms
# 493:	learn: 0.2254717	total: 99.3ms	remaining: 1.21ms
# 494:	learn: 0.2251865	total: 99.3ms	remaining: 1ms
# 495:	learn: 0.2247362	total: 99.4ms	remaining: 801us
# 496:	learn: 0.2242972	total: 99.4ms	remaining: 600us
# 497:	learn: 0.2240020	total: 99.5ms	remaining: 399us
# 498:	learn: 0.2237854	total: 99.5ms	remaining: 199us
# 499:	learn: 0.2237061	total: 99.6ms	remaining: 0us
# Training Accuracy:  0.9980602701901495
# Testing Accuracy:  0.9813923683643616

# %%
# Take Home Task:
# 1. Implement Decision Tree Regressor
# 2. Implement Random Forest Regressor
# 3. Implement Gradient Boosting Regressor
# 4. Implement XGBoost Regressor
# 5. Implement LightGBM Regressor
# 6. Implement CatBoost Regressor (https://catboost.ai/docs/en/concepts/python-reference_catboostclassifier)
# 7. Compare the results of all the models

# %% [markdown]
# # Happy Learning
